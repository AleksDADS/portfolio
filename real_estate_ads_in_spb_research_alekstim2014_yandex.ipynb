# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Открываем-и-изучаем-общую-информацию" data-toc-modified-id="Открываем-и-изучаем-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открываем и изучаем общую информацию</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Приводим-названия-столбцов-к-корректному-виду" data-toc-modified-id="Приводим-названия-столбцов-к-корректному-виду-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Приводим названия столбцов к корректному виду</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Меняем-типы-данных" data-toc-modified-id="Меняем-типы-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Меняем типы данных</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Обработка-аномальных-значений" data-toc-modified-id="Обработка-аномальных-значений-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Обработка аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Last_price" data-toc-modified-id="Last_price-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Last_price</a></span></li><li><span><a href="#Rooms" data-toc-modified-id="Rooms-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Rooms</a></span></li><li><span><a href="#Ceiling_height" data-toc-modified-id="Ceiling_height-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Ceiling_height</a></span></li><li><span><a href="#Living_area" data-toc-modified-id="Living_area-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Living_area</a></span></li><li><span><a href="#kitchen_area" data-toc-modified-id="kitchen_area-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>kitchen_area</a></span></li><li><span><a href="#nearest_airport_distance" data-toc-modified-id="nearest_airport_distance-2.5.6"><span class="toc-item-num">2.5.6&nbsp;&nbsp;</span>nearest_airport_distance</a></span></li></ul></li></ul></li><li><span><a href="#Создаем-новые-столбцы" data-toc-modified-id="Создаем-новые-столбцы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Создаем новые столбцы</a></span><ul class="toc-item"><li><span><a href="#Цена-за-квадратный-метр" data-toc-modified-id="Цена-за-квадратный-метр-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена за квадратный метр</a></span></li><li><span><a href="#Дата-публикации-объявления" data-toc-modified-id="Дата-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Дата публикации объявления</a></span></li><li><span><a href="#Тип-этажа-квартиры" data-toc-modified-id="Тип-этажа-квартиры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Тип этажа квартиры</a></span></li><li><span><a href="#Расстояние-до-центра-города-в-километрах" data-toc-modified-id="Расстояние-до-центра-города-в-километрах-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расстояние до центра города в километрах</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Визуализируем-общие-показатели" data-toc-modified-id="Визуализируем-общие-показатели-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Визуализируем общие показатели</a></span></li><li><span><a href="#Скорость-продажи-квартиры" data-toc-modified-id="Скорость-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Скорость продажи квартиры</a></span></li><li><span><a href="#Влияние-на-стоимость-квартиры" data-toc-modified-id="Влияние-на-стоимость-квартиры-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияние на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Количество-комнат" data-toc-modified-id="Количество-комнат-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Количество комнат</a></span></li><li><span><a href="#Категория-этажа" data-toc-modified-id="Категория-этажа-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Категория этажа</a></span></li><li><span><a href="#Дата-размещения" data-toc-modified-id="Дата-размещения-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Дата размещения</a></span></li></ul></li><li><span><a href="#Средняя-цена-за-квадратный-метр-в-TOP-10-населенных-пунктах" data-toc-modified-id="Средняя-цена-за-квадратный-метр-в-TOP-10-населенных-пунктах-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средняя цена за квадратный метр в TOP-10 населенных пунктах</a></span></li><li><span><a href="#Расстояние-до-центра" data-toc-modified-id="Расстояние-до-центра-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Расстояние до центра</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# * Данные сервиса Яндекс Недвижимость — архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
#
#
# * Цель — выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.

# %% [markdown]
# Описание данных
# О каждой квартире в базе содержится два типа данных: добавленные пользователем и картографические.
#
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `balcony` — число балконов
# - `ceiling_height` — высота потолков (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# - `first_day_exposition` — дата публикации
# - `floor` — этаж
# - `floors_total` — всего этажей в доме
# - `is_apartment` — апартаменты (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `last_price` — цена на момент снятия с публикации
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `locality_name` — название населённого пункта
# - `open_plan` — свободная планировка (булев тип)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `rooms` — число комнат
# - `studio` — квартира-студия (булев тип)
# - `total_area` — общая площадь квартиры в квадратных метрах (м²)
# - `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ## Открываем и изучаем общую информацию

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)  # Расширяем количество выводимых столбцов

data = pd.read_csv('real_estate_data.csv', sep='\t')
    
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15,20), bins=20);  # Строим гистограммы для числовых столбцов

# %% [markdown]
# <div class='alert alert-info'><b>
#     ВЫВОД:
#
# - Пропущенные значения есть в 14 столбцах из 22
# - У некоторых столбцов можно изменить тип данных
# - Названия нескольких столбцов некорректны
# - Наблюдаются выбросы
#
# </b></div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Приводим названия столбцов к корректному виду

# %%
data = data.rename(columns={
    'airports_nearest' : 'nearest_airport_distance',
    'cityCenters_nearest' : 'city_center_distance',
    'parks_around3000' : 'parks_around_3km',
    'parks_nearest' : 'nearest_park_distance',
    'ponds_around3000' : 'ponds_around_3km',
    'ponds_nearest' : 'nearest_pond_distance'
})
list(data.columns)  # Проверяем новые названия
# Out:
# ['total_images',
#  'last_price',
#  'total_area',
#  'first_day_exposition',
#  'rooms',
#  'ceiling_height',
#  'floors_total',
#  'living_area',
#  'floor',
#  'is_apartment',
#  'studio',
#  'open_plan',
#  'kitchen_area',
#  'balcony',
#  'locality_name',
#  'nearest_airport_distance',
#  'city_center_distance',
#  'parks_around_3km',
#  'nearest_park_distance',
#  'ponds_around_3km',
#  'nearest_pond_distance',
#  'days_exposition']

# %% [markdown]
# ### Обработка пропусков

# %%
data.isna().sum()  # Выводим количетсво пропусков
# Out:
# total_images                    0
# last_price                      0
# total_area                      0
# first_day_exposition            0
# rooms                           0
# ceiling_height               9195
# floors_total                   86
# living_area                  1903
# floor                           0
# is_apartment                20924
# studio                          0
# open_plan                       0
# kitchen_area                 2278
# balcony                     11519
# locality_name                  49
# nearest_airport_distance     5542
# city_center_distance         5519
# parks_around_3km             5518
# nearest_park_distance       15620
# ponds_around_3km             5518
# nearest_pond_distance       14589
# days_exposition              3181
# dtype: int64

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# Пропуски в столбце `balcony` заменяем на 0, так как, скорее всего, их просто нет.
#
# ---

# %%
data['is_apartment'] = data['is_apartment'].fillna('False')

# %% [markdown]
# Предполагаем, что пропуски в столбце `is_apartment` подразумевают отрицательный ответ и заменяем на False.
#
# ---

# %%
data['parks_around_3km'] = data['parks_around_3km'].fillna(0)
data['ponds_around_3km'] = data['ponds_around_3km'].fillna(0)

# %% [markdown]
# Заменим пропуски в `parks_around_3km` и `ponds_around_3km` на 0, так как их просто нет рядом, скорее всего.
#
# ---

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# Заменим пропуски в `ceiling_height` на медианное значение. Оно в пределах стандартной высоты согласно СНиП.
#
# ---

# %%
data.groupby('rooms')['living_area'].std()  # Находим стандартное отклонение жилплощади 
                                            # сгруппированное по количеству комнат.
# Out:
# rooms
# 0      6.549527
# 1      3.448422
# 2      6.129991
# 3     11.219835
# 4     23.329167
# 5     36.644486
# 6     42.743651
# 7     68.203364
# 8     41.550623
# 9     36.362428
# 10    22.047298
# 11     6.929646
# 12          NaN
# 14    37.971634
# 15          NaN
# 16          NaN
# 19          NaN
# Name: living_area, dtype: float64

# %% [markdown]
# Пропуски в `living_area` заменить на медианное значение по количеству комнат не лучшая идея, поскольку стандартное отклонение достаточно велико. Это может исказить данные, относительно зависимости цены.
#
# ---

# %%
len(data.query('kitchen_area.isna() and (studio == True or open_plan == True or is_apartment == True)'))
# Out:
# 231

# %% [markdown]
# Количество пропусков по площади кухни в  квартирах-студиях, с открытой планировкой или апартаментах. Оставляем.
#
# ---

# %% [markdown]
# <div class='alert alert-info'><b>
# ВЫВОД ПО ПРОПУСКАМ:
#
# - Заменили пропуски в столбцах:
#     - `balcony` - заменили на 0, так как, скорее всего, балконов там просто нет.
#     - `is_apartment` - очень много пропусков, предполагаем, что это отрицание. Меняем на False.
#     - `parks_around_3km` и `ponds_around_3km` - заменили на 0. Вероятнее всего парков и прудов в округе нет.
#     - `ceiling_height` - заменили на медиану. Она впределах стандартной высоты.
#
#
# - Оставили пропуски в столбцах, так как их просто не запонили, а логично заменить не представляется возможным в силу особенностей значений.
#     - `floors_total` - общее количетво этажей.
#     - `living_area` - Стандартное отклонение по количеству комнат велико, заменить нельзя - могут исказиться данные.
#     - `kitchen_area` - 231 из 2278 пропусков в квартирах-студиях, с открытой планировкой или апартаментах.
#     - `locality_name` - названия населенного пункта.
#     - `nearest_airport_distance`, `city_center_distance`, `nearest_park_distance`, `nearest_pond_distance` - расстояния.
#     - `days_exposition` - объявления не сняли с публикации.
#
#     </b></div>

# %% [markdown]
# ### Меняем типы данных

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')
data['first_day_exposition'].head()
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# Изменили на тип datetime, при этом отсекли время, так как нам важен день.
#
# ---

# %%
data['is_apartment'] = data['is_apartment'].astype('bool') # Изменили тип на bool

# %%
# Меняем на положительное целое в диапозоне 0-255, так как все подходят
data.astype({'balcony': 'uint8', 'rooms': 'uint8', 'floor': 'uint8',  
             'parks_around_3km': 'uint8', 'ponds_around_3km': 'uint8', 'total_images': 'uint8'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23699 non-null  int64
#  1   last_price                23699 non-null  float64
#  2   total_area                23699 non-null  float64
#  3   first_day_exposition      23699 non-null  datetime64[ns]
#  4   rooms                     23699 non-null  int64
#  5   ceiling_height            23699 non-null  float64
#  6   floors_total              23613 non-null  float64
#  7   living_area               21796 non-null  float64
#  8   floor                     23699 non-null  int64
#  9   is_apartment              23699 non-null  bool
#  10  studio                    23699 non-null  bool
#  11  open_plan                 23699 non-null  bool
#  12  kitchen_area              21421 non-null  float64
# ...

# %% [markdown]
# <div class='alert alert-info'><b>
#     ВЫВОД ПО ТИПАМ ДАННЫХ:
#
# - `first_day_exposition` изменили тип на `datetime`, чтобы было удобно работать с датами.
# - `is_apartment` изменили тип на `bool`, чтобы работать с булевым значением.
# - `balcony`, `rooms`, `floor`, `parks_around_3km`, `ponds_around_3km`, `total_images` - заменили на `uint8` для удобства и экономии памяти.
#
#     </b></div>

# %% [markdown]
# ### Обработка дубликатов

# %%
data.duplicated().sum()  # Явные дубликаты отсутствуют
# Out:
# 0

# %%
len(data['locality_name'].unique())  # Количество уникальных названий
# Out:
# 365

# %%
data['locality_name'] = data['locality_name'].str.lower()
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('городской поселок', 'поселок городского типа')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'поселок')
len(data['locality_name'].unique())  # Количество обновленных уникальных названий
# Out:
# 323

# %% [markdown]
# <div class='alert alert-info'><b>
#     ВЫВОД ПО ДУБЛИКАТАМ:
#
# - Явные дубликаты отстутствуют.
# - Неявных 42 убрали, заменив 'ё' на 'е', 'городской поселок' и 'поселок городского типа' на 'поселок', так как нам важно само название, а не тип поселка.
#
#     </b></div>

# %% [markdown]
# ### Обработка аномальных значений

# %%
data.describe().round(2)
# Out:
#        total_images    last_price  total_area     rooms  ceiling_height  \
# count      23699.00  2.369900e+04    23699.00  23699.00        23699.00
# mean           9.86  6.541549e+06       60.35      2.07            2.72
# std            5.68  1.088701e+07       35.65      1.08            0.99
# min            0.00  1.219000e+04       12.00      0.00            1.00
# 25%            6.00  3.400000e+06       40.00      1.00            2.60
# 50%            9.00  4.650000e+06       52.00      2.00            2.65
# 75%           14.00  6.800000e+06       69.90      3.00            2.70
# max           50.00  7.630000e+08      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count      23613.00     21796.00  23699.00      21421.00  23699.00
# mean          10.67        34.46      5.89         10.57      0.59
# std            6.60        22.03      4.89          5.91      0.96
# ...

# %% [markdown]
# Наблюдаются аномальные значения в:
# `last_price`, `rooms`, `ceiling_height`, `living_area`, `kitchen_area`, `nearest_airport_distance`.
#
# ---

# %% [markdown]
# #### Last_price

# %% [markdown]
# Минимальное значение 12190, максимальное 763млн. 50% наблюдений в диапозоне от 3.4млн до 6.8 млн.

# %%
data.hist('last_price', bins=30, range=(0, 1e+06));      # Диапозон от 0 до 1млн
data.hist('last_price', bins=30, range=(1e+08, 8e+08));  # Диапозон от 100млн до 800млн

# %%
data = data.drop(data[data['last_price'] < 1e+05].index)
data = data.drop(data[data['last_price'] > 1e+08].index)

# %% [markdown]
# Удаляем квартиры с ценой до 100т и свыше 100млн. От 30 до 100млн будем рассматривать как сегмент элитной недвижимости.
#
# ---

# %% [markdown]
# #### Rooms

# %%
data.query('rooms == 0')['rooms'].count()  # Количество нулевых значений
# Out:
# 197

# %%
data.query('rooms == 0 and (studio == True or open_plan == True)')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1   2450000.0       27.00           2017-03-30      0
# 349               4   2320000.0       25.00           2017-09-27      0
# 440               8   2480000.0       27.11           2018-03-12      0
# 508               0   3375000.0       34.40           2017-03-28      0
# 608               2   1850000.0       25.00           2019-02-20      0
# ...             ...         ...         ...                  ...    ...
# 23210             7   3200000.0       26.00           2017-09-01      0
# 23442             0   2500000.0       27.70           2017-09-28      0
# 23554            15   3350000.0       26.00           2018-09-07      0
# 23592            10   1450000.0       29.00           2017-11-11      0
# 23637             8   2350000.0       26.00           2018-06-26      0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Нулевые значения есть либо в квартирах-студиях, либо с открытой планировкой. Оставляем как признак принадлежности к тому или иному виду квартир.
#
# ---

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7938
# 3     5810
# 4     1171
# 5      316
# 0      197
# 6      100
# 7       54
# 8       10
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# Name: rooms, dtype: int64

# %%
data = data.drop(data[data['rooms'] > 9].index)

# %% [markdown]
# Удаляем квартиры с количеством комнат более 9.
#
# ---

# %% [markdown]
# #### Ceiling_height

# %% [markdown]
# Согласно СНиП минимально допустимая высота потолков в многоквартирных домах 2.5 метра. Стандарт 2.5 - 3.2 метра. Бывают двухуровневые квартиры с высотой 6 метров.

# %%
data.query('ceiling_height > 6')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.0        55.2           2018-07-12      2
# 3148             14   2900000.0        75.0           2018-11-12      3
# 3474              3   1400000.0        30.0           2018-03-16      1
# 4643              0   4300000.0        45.0           2018-02-01      2
# 4876              7   3000000.0        25.0           2017-09-27      0
# 5076              0   3850000.0        30.5           2018-10-03      1
# 5246              0   2500000.0        54.0           2017-10-13      2
# 5669              4   4400000.0        50.0           2017-08-08      2
# 5807             17   8150000.0        80.0           2019-01-09      2
# 5863             20   5650000.0        45.0           2018-08-15      1
# 6246              6   3300000.0        44.4           2019-03-25      2
# 9379              5   3950000.0        42.0           2017-03-26      3
# ...

# %%
data.loc[data['ceiling_height'] > 6, 'ceiling_height'] /= 10
data = data.drop(data[data['ceiling_height'] > 6].index)
data = data.drop(data[data['ceiling_height'] < 2.5].index)

# %% [markdown]
# Квартиры с высотой потолков до 2.5 метров и более 6 метров удалаяем, так как они не проходят по СНиП. **Кроме тех**, которые в диапозоне от 25 до 60 метров. Их принимаем за опечатку и исправляем, поделив на 10.
#
# ---

# %% [markdown]
# #### Living_area

# %% [markdown]
# Наблюдаются подозрительно маленькие значения.

# %%
data.query('living_area < 10')['living_area'].count()  # Количетво квартир с жилой площадью менее 10м
# Out:
# 25

# %%
data.hist('living_area', range=(0, 20), bins=20);

# %%
data = data.drop(data[data['living_area'] < 10].index)

# %% [markdown]
# Удаляем квартиры с жилой площадью менее 10 кв.м.
#
# ---

# %% [markdown]
# #### kitchen_area

# %% [markdown]
# Есть очень маленькие значения - 1.3, а есть огромные - 112.

# %%
data.hist('kitchen_area', range=(0, 7), bins=20);
data.hist('kitchen_area', range=(30, 115), bins=20);

# %%
data = data.drop(data[data['kitchen_area'] < 3].index)
data = data.drop(data[data['kitchen_area'] > 60].index)

# %% [markdown]
# Удаляем квартиры с площадью кухни меньше 3 и больше 60 кв.м.
#
# ---

# %% [markdown]
# #### nearest_airport_distance

# %% [markdown]
# Большие расстояния вполне вероятны, а вот квартира в аэропорту наврядли.

# %%
data.query('nearest_airport_distance < 1000')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21085             0   7000000.0        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 21085             2.7           9.0         19.8      3          True   False
#
#        open_plan  kitchen_area  balcony    locality_name  \
# 21085      False           6.0      2.0  санкт-петербург
#
#        nearest_airport_distance  city_center_distance  parks_around_3km  \
# 21085                       0.0               22801.0               0.0
#
#        nearest_park_distance  ponds_around_3km  nearest_pond_distance  \
# 21085                    NaN               0.0                    NaN
#
#        days_exposition
# 21085             60.0

# %%
data.loc[data['nearest_airport_distance'] < 1000, 'nearest_airport_distance'] = np.nan

# %% [markdown]
# Заменим единственное нулевое значение на NaN.
#
# ---

# %%
data = data.reset_index(drop=True) # Сбрасываем индексы

# %%
data.describe().round(2)
# Out:
#        total_images   last_price  total_area     rooms  ceiling_height  \
# count      23515.00     23515.00    23515.00  23515.00        23515.00
# mean           9.85   6220714.99       59.80      2.06            2.70
# std            5.68   6269519.22       32.86      1.04            0.22
# min            0.00    430000.00       12.00      0.00            2.50
# 25%            6.00   3420000.00       40.00      1.00            2.60
# 50%            9.00   4650000.00       52.00      2.00            2.65
# 75%           14.00   6750000.00       69.60      3.00            2.70
# max           50.00  99000000.00      517.00      9.00            5.80
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count      23429.00     21623.00  23515.00      21255.00  23515.00
# mean          10.69        34.19      5.90         10.47      0.59
# std            6.60        20.73      4.89          5.38      0.96
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23515 entries, 0 to 23514
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23515 non-null  int64
#  1   last_price                23515 non-null  float64
#  2   total_area                23515 non-null  float64
#  3   first_day_exposition      23515 non-null  datetime64[ns]
#  4   rooms                     23515 non-null  int64
#  5   ceiling_height            23515 non-null  float64
#  6   floors_total              23429 non-null  float64
#  7   living_area               21623 non-null  float64
#  8   floor                     23515 non-null  int64
#  9   is_apartment              23515 non-null  bool
#  10  studio                    23515 non-null  bool
#  11  open_plan                 23515 non-null  bool
#  12  kitchen_area              21255 non-null  float64
# ...

# %% [markdown]
# <div class='alert alert-info'><b>
#     ВЫВОД ПО АНОМАЛЬНЫМ ЗНАЧЕНИЯМ
#
#
# - В пределах допустимых значений:
#     - `total_images` - количество фотографий от 0 до 50. Для нас не важно.
#     - `total_area` - общая площадь от 12 до 517. Что ж, квартиры разные бывают.
#     - `floors_total` - общее количество этажей от 1 до 60. Вполне реально.
#     - `floor` - на каком этаже квартира. От 1 до 33.
#     - `balcony` - количество балконов от 0 до 5.
#     - `city_center_distance` - расстояние до центра от 180м до 66км. Кто-то в центре, а кто-то далеко очень.
#     - `parks_around_3km` и `ponds_around_3km` - количество парков и прудов в радиусе 3км. От 0 до 3.
#     - `nearest_park_distance` - расстояние до ближайшего парка от 1 до 3190м. Бывают дома, у которых за забором сразу парк.
#     - `nearest_pond_distance` - расстояние до ближайшего пруда от 13 до 1344м. У кого-то дом рядом с прудом.
#     - `days_exposition` - количество дней размещения объявления от 1 до 1580 дней. У кого-то за 1 день покупают, а кто-то ждет более 4х лет. Вполне правдоподобно.
#
# - Изменили:
#     - `last_price` - удалили квартиры с ценой до 100т и свыше 100млн.
#     - `rooms` - удалили квартиры с количеством комнат более 9.
#     - `ceiling_height` - исправили опечатки со значениями 25-32м. Удалили квартиры с высотой потолков до 2.5м и более 6м.
#     - `living_area` - убрали квартиры с жилой площадью до 10м.
#     - `kitchen_area` - удалили квартиры с площадью кухни до 3м и свыше 60м.
#     - `nearest_airport_distance` - заменили единственное нулевое значение на NaN.
#
#     </b></div>

# %% [markdown]
# ## Создаем новые столбцы

# %% [markdown]
# Для удобства нахождения взаимосвязей

# %% [markdown]
# ### Цена за квадратный метр

# %%
data['square_meter_price'] = data['last_price'] / data['total_area']

# %% [markdown]
# ### Дата публикации объявления

# %% [markdown]
# Создадим 3 новых столбца. С днем недели, месяцем и годом публикации. И сразу присвоим тип uint8.

# %%
data['exposition_weekday'] = data['first_day_exposition'].dt.weekday.astype('uint8')  # День недели
data['exposition_month'] = data['first_day_exposition'].dt.month.astype('uint8')      # Месяц
data['exposition_year'] = data['first_day_exposition'].dt.year.astype('uint16')       # Год

# %% [markdown]
# ### Тип этажа квартиры

# %% [markdown]
# Создадим столбец с тремя типами этажности квартир - `первый`, `последний` и `другой`.

# %%
floor_compare = []  # Пустой список
for i in range(len(data['floors_total'])):  # Создали цикл с условиями и добавлением категорий в список.
    if data['floor'][i] == 1:
        floor_compare.append('первый')
    elif data['floor'][i] == data['floors_total'][i]:
        floor_compare.append('последний')
    else:
        floor_compare.append('другой')
        
floor_compare = pd.Series(floor_compare)  # Превратили список в Series

# %%
data['floor_category'] = floor_compare  # Создали новый столбец с категориями

# %%
data['floor_category'].value_counts()
# Out:
# другой       17327
# последний     3293
# первый        2895
# Name: floor_category, dtype: int64

# %% [markdown]
# ### Расстояние до центра города в километрах

# %%
def m_to_km(m):  # Создаем функцию для округления
    try:
        m /= 1000
        return round(m)
    except:
        pass  # На случай NaN

# %%
data['city_center_distance_km'] = data['city_center_distance'].apply(m_to_km)  # Применяем функцию для создания столбца

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23515 entries, 0 to 23514
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23515 non-null  int64
#  1   last_price                23515 non-null  float64
#  2   total_area                23515 non-null  float64
#  3   first_day_exposition      23515 non-null  datetime64[ns]
#  4   rooms                     23515 non-null  int64
#  5   ceiling_height            23515 non-null  float64
#  6   floors_total              23429 non-null  float64
#  7   living_area               21623 non-null  float64
#  8   floor                     23515 non-null  int64
#  9   is_apartment              23515 non-null  bool
#  10  studio                    23515 non-null  bool
#  11  open_plan                 23515 non-null  bool
#  12  kitchen_area              21255 non-null  float64
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %%
data.describe().round(2)
# Out:
#        total_images   last_price  total_area     rooms  ceiling_height  \
# count      23515.00     23515.00    23515.00  23515.00        23515.00
# mean           9.85   6220714.99       59.80      2.06            2.70
# std            5.68   6269519.22       32.86      1.04            0.22
# min            0.00    430000.00       12.00      0.00            2.50
# 25%            6.00   3420000.00       40.00      1.00            2.60
# 50%            9.00   4650000.00       52.00      2.00            2.65
# 75%           14.00   6750000.00       69.60      3.00            2.70
# max           50.00  99000000.00      517.00      9.00            5.80
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count      23429.00     21623.00  23515.00      21255.00  23515.00
# mean          10.69        34.19      5.90         10.47      0.59
# std            6.60        20.73      4.89          5.38      0.96
# ...

# %% [markdown]
# ### Визуализируем общие показатели

# %%
ax = sns.histplot(data,
                  x='total_area',
                  element='step',
                  color='lightseagreen')

ax.set_title('Общая площадь')
ax.set(xlabel='кв.м.', ylabel='количество квартир', xlim=(0, 200))
ax.axvline(data['total_area'].mean(), color='r', ls='--')
ax.axvline(data['total_area'].median(), color='b', ls='--')
ax.legend(['площадь', 'среднее', 'медиана']);

# %% [markdown]
# Большинство квартир с общей площадью в диапозоне 30-80 кв.м.
#
# ---

# %%
ax = sns.histplot(data,
                  x='living_area',
                  element='step',
                  color='lightseagreen')

ax.set_title('Жилая площадь')
ax.set(xlabel='кв.м.', ylabel='количество квартир', xlim=(0, 100))
ax.axvline(data['living_area'].mean(), color='r', ls='--')
ax.axvline(data['living_area'].median(), color='b', ls='--')
ax.legend(['площадь', 'среднее', 'медиана']);

# %% [markdown]
# Большинство квартир с жилой площадью в диапозоне 18-50 кв.м. Наблюдаются 3 пика - 18, 30, 42.
#
# ---

# %%
ax = sns.histplot(data,
                  x='kitchen_area',
                  element='step',
                  color='lightseagreen')

ax.set_title('Площадь кухни')
ax.set(xlabel='кв.м.', ylabel='количество квартир', xlim=(0, 30))
ax.axvline(data['kitchen_area'].mean(), color='r', ls='--')
ax.axvline(data['kitchen_area'].median(), color='b', ls='--')
ax.legend(['площадь', 'среднее', 'медиана']);

# %% [markdown]
# В основной массе кухни небольшие - 5-15 кв.м.
#
# ---

# %%
ax = sns.histplot(data,
                  x=(data['last_price']/1000000),
                  element='step',
                  color='lightseagreen')

ax.set_title('Стоимость')
ax.set(xlabel='млн.р.', ylabel='количество квартир', xlim=(0, 20))
ax.axvline((data['last_price']/1000000).mean(), color='r', ls='--')
ax.axvline((data['last_price']/1000000).median(), color='b', ls='--')
ax.legend(['площадь', 'среднее', 'медиана']);

# %% [markdown]
# Больше всего квартир стоимостью до 10млн. От 10 до 20 немного, но, видимо, пользуются спросом. Очень длинный хвост вправо, элитная недвижимость.
#
# ---

# %%
data.groupby('rooms')['rooms'].count().plot(kind='bar')
plt.title('количество комнат')
plt.xlabel('комнаты')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Самые популярные 1- и 2-комнатные квартиры. Но 3-комнатных тоже порядочно.
#
# ---

# %%
data.hist('ceiling_height', figsize=(9, 4), bins=20, range=(2.5, 4))
plt.title('высота потолков')
plt.xlabel('метры')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Высота потолков как и по стандарту 2.5-3.2м. Стандартнее всего 2.65м
#
# ---

# %%
data.hist('floor', figsize=(9, 4), bins=30)
plt.title('расположение на этаже')
plt.xlabel('этаж')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Больше всего квартир с расположением до 5 этажа.
#
# ---

# %%
data['floor_category'].hist(figsize=(4, 4), bins=6)
plt.title('категория этажа')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Квартир на любом этаже, кроме 1-го и последнего в разы больше.
#
# ---

# %%
data.hist('floors_total', figsize=(9, 4), bins=30, range=(0, 30))
plt.title('этажность')
plt.xlabel('количество этажей в здании')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Как видим, 5-ти и 9-ти этажных зданий все ещё большинство.
#
# ---

# %%
data.hist('city_center_distance', figsize=(9, 4), bins=100, range=(0, 60000))
plt.title('расстояние до центра')
plt.xlabel('метры')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Основная масса квартир расположена в пределах 20-ти км от центра. Но чаще на расстоянии 10-15 км.
#
# ---

# %%
data.hist('nearest_airport_distance', figsize=(9, 4), bins=100, range=(0, 80000))
plt.title('расстояние до ближайшего аэропорта')
plt.xlabel('метры')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Распределение квартир по удаленности от аэропорта отдаленно напоминает нормальное. От 5 до 50 км.
#
# ---

# %%
data.hist('nearest_park_distance', figsize=(9, 4), bins=50, range=(0, 3000))
plt.title('расстояние до ближайшего парка')
plt.xlabel('метры')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Если рядом есть парк, то скорее всего, он не дальше 700 метров от дома.
#
# ---

# %%
data.hist('exposition_weekday', figsize=(9, 4), bins=7)
plt.title('день недели публикации объявления')
plt.xlabel('пн-вт-ср-чт-пт-сб-вс')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# Публикуют объявления, как правило, в рабочии дни. Оно и понятно
#
# ---

# %%
data.hist('exposition_month', figsize=(9, 4), bins=12)
plt.title('месяц публикации объявления')
plt.ylabel('количество квартир')
plt.show()

# %% [markdown]
# В январе, декабре и мае мало кто выставляет объявление. С февраля по апрель больше всего объявлений. С июля по октябрь плавный рост.
#
# ---

# %% [markdown]
# <div class='alert alert-info'><b>
#     ВЫВОД ПО ВИЗУАЛИЗАЦИИ ОБЩИХ ПОКАЗАТЕЛЕЙ:
#
# - Общая площадь в диапозоне 30-80 кв.м.
# - Жилая площадь в диапозоне 18-50 кв.м. Наблюдаются 3 пика - 18, 30, 42.
# - Кухни в основном небольшие - 5-15 кв.м.
# - Больше всего квартир стоимостью до 10млн. От 10 до 20 немного, но пользуются спросом. Очень длинный хвост вправо, элитная недвижимость.
# - Самые популярные 1- и 2-комнатные квартиры. Но 3-комнатных тоже немало.
# - Высота потолков как и по стандарту 2.5-3.2м. Стандартнее всего 2.65м
# - Больше всего квартир с расположением до 5 этажа.
# - Квартир на любом этаже, кроме 1-го и последнего в разы больше.
# - 5-ти и 9-ти этажных зданий все ещё большинство.
# - Основная масса квартир расположена в пределах 20-ти км от центра. Но чаще на расстоянии 10-15 км.
# - Распределение квартир по удаленности от аэропорта отдаленно напоминает нормальное. От 5 до 50 км.
# - Если рядом есть парк, то скорее всего, он не дальше 700 метров от дома.
# - Публикуют объявления, как правило, в рабочии дни. Оно и понятно
# - В январе, декабре и мае мало кто выставляет объявление. С февраля по апрель больше всего объявлений. С июля по октябрь плавный рост.
#
#     </b></div>

# %% [markdown]
# ### Скорость продажи квартиры

# %%
data.hist('days_exposition', bins=100)  
plt.title('количество дней до снятия с публикации')
plt.xlabel('дни')
plt.ylabel('количество квартир')
plt.show()

data.hist('days_exposition', bins=100, range=(0, 100))
plt.title('количество дней до снятия с публикации')
plt.xlabel('дни')
plt.ylabel('количество квартир')
plt.show()
print('Среднее:', round(data['days_exposition'].mean(), 2),
      'Медиана:', data['days_exposition'].median(), sep='\n')  #Среднее и медиана
# Out:
# Среднее:
# 180.65
# Медиана:
# 95.0

# %% [markdown]
# Здесь наблюдаем явное распределение
# Пуассона. В `среднем` квартиры продаются за полгода. `Медиана` в 2 раза меньше. Есть квартиры, которые продаются по 2-4 года, за счет этого такая разница между средним и медианой. Будем считать, что `быстрая` продажа квартиры осуществляется за 3 месяца, а `долгая` - свыше полугода. Есть пики на 45-м, 60-м и 90-м дне. Возможно это связано с системой удаления объявлений.
#
# ---

# %% [markdown]
# ### Влияние на стоимость квартиры

# %% [markdown]
# Создадим новый датафрейм для удобства выявления зависимости цены.

# %%
col_corr = (['last_price', 'total_area', 'living_area', 'kitchen_area', 'rooms',  # Список столбцов
            'floor_category'])  
data_corr = pd.DataFrame(data=data, columns=col_corr)  # Создаем новый датафрейм
data_corr.corr().round(2)  # Таблица корреляций
# Out:
#               last_price  total_area  living_area  kitchen_area  rooms
# last_price          1.00        0.77         0.69          0.58   0.47
# total_area          0.77        1.00         0.94          0.59   0.77
# living_area         0.69        0.94         1.00          0.40   0.85
# kitchen_area        0.58        0.59         0.40          1.00   0.25
# rooms               0.47        0.77         0.85          0.25   1.00

# %% [markdown]
# #### Площадь

# %%
col_corr_area = ['total_area', 'living_area', 'kitchen_area']  # Создадим датафрейм для вичисления влияния площади на цену
data_corr_area = pd.DataFrame(data=data_corr, columns=col_corr_area)
data_corr_area['last_price'] = data_corr['last_price']/1000000  # Разделим значения на млн, чтобы на графике было понятнее
data_corr_area
# Out:
#        total_area  living_area  kitchen_area  last_price
# 0          108.00         51.0         25.00      13.000
# 1           40.40         18.6         11.00       3.350
# 2           56.00         34.3          8.30       5.196
# 3          159.00          NaN           NaN      64.900
# 4          100.00         32.0         41.00      10.000
# ...           ...          ...           ...         ...
# 23510      133.81         73.3         13.83       9.700
# 23511       59.00         38.0          8.50       3.100
# 23512       56.70         29.7           NaN       2.500
# 23513       76.75          NaN         23.30      11.475
# 23514       32.30         12.3          9.00       1.350
#
# [23515 rows x 4 columns]

# %%
for i in range(3):  # Создаем цикл для построения графиков
    ttl = ['общая площадь', 'жилая площадь', 'площадь кухни']
    data_corr_area.plot(x='last_price', y=col_corr_area[i],
                        figsize=(8, 5), kind='scatter', alpha=0.1)
    
    plt.title(ttl[i])
    plt.xlabel('млн.р.')
    plt.ylabel('кв.м.')
    plt.show()

# %% [markdown]
# Взаимосвязь четко прослеживается на графиках.
# Корреляция между ценой и:
# - общей площадью - 0.77
# - жилой площадью - 0.69
# - площадью кухни - 0.58
#
# Виден большой разброс цен после:
# - 150 кв.м. общей площади
# - 60 кв.м жилой площади
# - 20 кв.м. площади кухни
#
# ---

# %% [markdown]
# #### Количество комнат

# %%
(data_corr.pivot_table(index='rooms', values='last_price')['last_price']/1000000)\
.plot(y='last_price', kind='bar', legend=False)

plt.title('количество комнат')
plt.xlabel('комнаты')
plt.ylabel('млн.р.')
plt.show()

# %% [markdown]
# Цена растет вместе с количеством комнат, логично, ведь корреляция между количеством комнат и общей площадью/жилой площадью - 0.77 и 0.85 соответственно. Отличаются только 8-ми комнатные квартиры.
#
# ---

# %% [markdown]
# #### Категория этажа

# %%
data_corr.pivot_table(index='floor_category', values='last_price')\
         .plot(y='last_price', kind='bar', legend=False)
plt.title('категория этажа (среднее)')
plt.xlabel(None)
plt.ylabel('млн.р.')
plt.show()

# %%
data_corr.pivot_table(index='floor_category', values='last_price', aggfunc='median')\
         .plot(y='last_price', kind='bar', legend=False)
plt.title('категория этажа (медиана)')
plt.xlabel(None)
plt.ylabel('млн.р.')
plt.show()

# %% [markdown]
# Категория этажа квартиры не сильно влияет на ценообразование, но все-же, квартиры на 1-м этаже дешевле чем на последнем, а квартиры на последнем этаже немного дешевле, чем на любом другом.
#
# ---

# %% [markdown]
# #### Дата размещения

# %%
exposition_col_name_eng = ['exposition_weekday','exposition_month','exposition_year']
exposition_col_name_ru = ['день недели', 'месяц', 'год']
# Создаем цикл для построения графиков со средней и медианной ценой в зависимости от публикации объявления по
# дням недели, месяцам и годам соответсвенно
for i in range(3):
    (  
    (data.pivot_table(index=exposition_col_name_eng[i], values='last_price')['last_price']/1000000)
    .plot(y='last_price', kind='bar', figsize=(6, 3), title=exposition_col_name_ru[i] + ' (среднее)', legend=False)
    )
    plt.xlabel(None)
    plt.ylabel('млн.р.')
    plt.show()
    
    (  
    (data.pivot_table(index=exposition_col_name_eng[i], values='last_price', aggfunc='median')['last_price']/1000000)
    .plot(y='last_price', kind='bar', figsize=(6, 3), title=exposition_col_name_ru[i] + ' (медиана)', legend=False)
    )
    plt.xlabel(None)
    plt.ylabel('млн.р.')
    plt.show()
    print('\n' * 3)

# %% [markdown]
# - Среднее и медианное значение не зависит от дня недели.
# - Среднее и медианное значение не зависит от месяца.
# - Среднее и медианное значение не зависит от года. Только в 2014 году цены были выше.
#
# ---

# %% [markdown]
# <div class='alert alert-info'><b>
#     ВЫВОД О ВЛИЯНИИ НА ЦЕНУ:
#
# - На цену влияет больше всего площадь квартиры. По убыванию соответственно - общая, жилая и площадь кухни.
# - Также есть взаимосвязь с количеством комнат. Но это скорее ложная корреляция, поскольку с ростом количества комнат растет и площадь квартиры, она то как раз и влияет на цену.
# - Категория этажа квартиры не сильно влияет на ценообразование, но все-же, квартиры на 1-м этаже дешевле чем на последнем, а квартиры на последнем этаже немного дешевле, чем на любом другом.
# - Влияние даты размещения объявления на цену отсутсвует. Только в 2014 году цены были выше. Веротнее всего из-за экономичсекого кризиса.
#
# </b></div>

# %% [markdown]
# ### Средняя цена за квадратный метр в TOP-10 населенных пунктах

# %%
top_10 = list(data.groupby('locality_name')['square_meter_price'].count()
              .sort_values(ascending=False).head(10).index)
top_10  # Создали список топ-10 с названиями населенных пунктов по кол-ву объявлений
# Out:
# ['санкт-петербург',
#  'поселок мурино',
#  'поселок шушары',
#  'всеволожск',
#  'пушкин',
#  'колпино',
#  'поселок парголово',
#  'гатчина',
#  'деревня кудрово',
#  'выборг']

# %%
(  # На основе среза по нашему списку топ-10 создаем сводную таблицу со средней ценой за кв.м. по населенным пунктам
    data.query('locality_name in @top_10')
    .pivot_table(index='locality_name', values='square_meter_price')
    .sort_values(by='square_meter_price', ascending=False)
)  # и сортируем
# Out:
#                    square_meter_price
# locality_name
# санкт-петербург         113419.803480
# пушкин                  102900.331693
# деревня кудрово          92473.547576
# поселок парголово        90205.423758
# поселок мурино           85655.287786
# поселок шушары           78703.263242
# колпино                  75443.972838
# гатчина                  68746.146763
# всеволожск               68719.320400
# выборг                   58238.143141

# %%
(  # Строим диаграмму
    data.query('locality_name in @top_10')
    .pivot_table(index='locality_name', values='square_meter_price')
    .sort_values(by='square_meter_price')
    .plot(kind='barh', figsize=(9, 5), legend=False)
)
plt.title('TOP-10 цен за кв.м.')
plt.xlabel('рубли')
plt.ylabel('')
plt.show()

# %% [markdown]
# - Самый дорогой квадратный метр жилья в Санкт-Петербурге - 113.4 т.р.
# - Самый дешевый из TOP-10 квадратный метр в Выборге - 58.2 т.р.
#
# ---

# %% [markdown]
# ### Расстояние до центра

# %% [markdown]
# Найдем среднюю цену квартир по отдаленности от центра по каждому километру.

# %%
(    
    (data.query('locality_name == "санкт-петербург"')
    .pivot_table(index='city_center_distance_km', values='last_price')['last_price']/1000000)
    .plot(kind='bar', figsize=(9, 5), legend=False)
)
plt.title('расстояние до центра')
plt.xlabel('км')
plt.ylabel('млн.р.')
plt.show()

# %% [markdown]
# - На графике видно, что сильно выделяется нулевой километр, то есть на расстоянии меньше 500 метров от центра.
# - Также выделяется сегмент до 8 км, изменение цены происходит не пропорционально расстоянию. С 1-го по 3-й цена снижается, а с   4-го по 7-й растет. Видимо сказывается принадлежность к "определенным" районам.
# - Далее наблюдаем почти плавное снижение цен. Но есть небольшие всплески на 13, 15, 20-23 и особенно на 27-м километре.
#     Вероятно это на этих расстояниях расположены элитные районы.
#
# ---

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Наблюдаем следующие самые популярные параметры квартир:
# - Площадь в диапозоне
#     - общая 30 - 80 кв.м.
#     - жилая 18 - 50 кв.м.
#     - кухни 5 - 15 кв.м.
# - Стоимость 3.5 - 6.5 млн.р.
# - Комнатность 1 - 2
# - Высота потолков 2.65м
# - Этаж до 5-го. Любой другой, кроме 1-го и последнего, в несколько раз чаще встречается.
# - Большинство квартир расположены в 5-ти и 9-ти этажных зданиях.
# - Удаленность
#     - от центра в пределах 20-ти км.
#     - от аэропорта в дапозоне от 15 до 35 км.
# - Около 30% квартир находятся рядом с парком и столько же рядом с прудом.
# - Публикуют объявления в рабочие дни.
# - Февраль - апрель и сентябрь - октябрь самый сезон публикации объявлений.
# - В среднем квартиры продаются за 3 - 6 месяцев.
# - Самая высокая средняя стоимость 1-го квадратного метра в Санкт-Петербурге - 113.4 т.р.
#
# Влияние на ценообразование:
# - Сильнее всего влияет общая площадь квартиры в сочетании с количеством комнат.
# - Приближенность к центру города Санкт-Петербургу также оказывает сильное влияние. Самые дорогие в пределах 500 метров от центра. Сильно от остальных отличаются цены квартир на расстоянии до 8 километров.
# - Квартиры на 1-м этаже дешевле, чем на последнем, а те в свою очередь, немного дешевле, чем на любом другом.
# - Дата размещения объявления никак не влияет на цену. Только в 2014 году цены были выше. Веротнее всего, из-за экономичсекого кризиса.
#
#
# </b></div>
